# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Storing Gaming Laptops info
gaming_laptops_df = pd.read_csv("newegg_gaming_laptops.csv", sep = ",")
gaming_laptops_df.head()
# Out:
#                                                 name     price brand  \
# 0  MSI GL Series GL73 9RCX-029 17.3" 60 Hz Intel ...       799   MSI
# 1  ASUS ZenBook Pro Duo UX581GV Gaming and Busine...  2,499.99  ASUS
# 2  MSI GL Series GL65 9SC-003 15.6" Intel Core i7...       849   MSI
# 3  MSI GP Series GP65 Leopard 9SF-240 15.6" 144 H...  1,599.00   MSI
# 4  MSI GL Series GL75 9SDK-063 17.3" 144 Hz IPS I...  1,199.00   MSI
#
#                     series                 model  rating  \
# 0                GL Series         GL73 9RCX-029     4.0
# 1  ZenBook Pro Duo UX581GV                   NaN     NaN
# 2                GL Series          GL65 9SC-003     5.0
# 3                GP Series  GP65 Leopard 9SF-240     5.0
# 4                GL Series         GL75 9SDK-063     4.0
#
#                        os               cpu_type         cpu_speed  \
# 0  Windows 10 Home 64-bit  Intel Core i7 9th Gen  9750H (2.60 GHz)
# 1          Windows 10 Pro  Intel Core i7 9th Gen          2.60 GHz
# ...

# %%
#Replacing the NaN Values that are in Gaming Laptops info
gaming_laptop_title = gaming_laptops_df.loc[0,"name"]
gaming_laptop_title.split(" ")
gaming_laptops_df = gaming_laptops_df.fillna(-1) #Will get back to later
gaming_laptops_df
# Out:
#                                                   name     price        brand  \
# 0    MSI GL Series GL73 9RCX-029 17.3" 60 Hz Intel ...       799          MSI
# 1    ASUS ZenBook Pro Duo UX581GV Gaming and Busine...  2,499.99         ASUS
# 2    MSI GL Series GL65 9SC-003 15.6" Intel Core i7...       849          MSI
# 3    MSI GP Series GP65 Leopard 9SF-240 15.6" 144 H...  1,599.00          MSI
# 4    MSI GL Series GL75 9SDK-063 17.3" 144 Hz IPS I...  1,199.00          MSI
# 5    MSI GL Series GL65 9SDK-034 15.6" Intel Core i...  1,049.00          MSI
# 6    ASUS - Gaming Laptop - 15.6" 120 Hz IPS-level ...       999         ASUS
# 7    MSI GL Series GL65 9SEK-065 15.6" 144 Hz IPS I...  1,249.00          MSI
# 8    MSI GF Series GF63 THIN 9SC 15.6" 60 Hz IPS In...       799          MSI
# 9    ASUS - Gaming Laptop - 17.3" 120 Hz IPS-type -...  1,099.99         ASUS
# 10   MSI GF Series GF65 THIN 9SD 15.6" 120 Hz IPS I...       974           -1
# ...

# %%
#Converting Rating Values into Integers
for i in range(len(gaming_laptops_df["rating"])):
    gaming_laptops_df["rating"] = int(gaming_laptops_df.loc[i,"rating"])
    print(gaming_laptops_df["rating"])
# Out:
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
# 5      4
# 6      4
# 7      4
# 8      4
# 9      4
# 10     4
# 11     4
# 12     4
# 13     4
# 14     4
# 15     4
# 16     4
# 17     4
# 18     4
# 19     4
# 20     4
# 21     4
# 22     4
# 23     4
# 24     4
# 25     4
# 26     4
# 27     4
# 28     4
# 29     4
#       ..
# 506    4
# 507    4
# 508    4
# 509    4
# 510    4
# 511    4
# 512    4
# 513    4
# 514    4
# 515    4
# 516    4
# 517    4
# 518    4
# 519    4
# 520    4
# 521    4
# 522    4
# 523    4
# 524    4
# 525    4
# 526    4
# 527    4
# 528    4
# 529    4
# 530    4
# 531    4
# 532    4
# 533    4
# 534    4
# 535    4
# Name: rating, Length: 536, dtype: int64
# 0      4
# 1      4
# 2      4
# 3      4
# 4      4
# 5      4
# 6      4
# 7      4
# 8      4
# 9      4
# 10     4
# 11     4
# 12     4
# 13     4
# 14     4
# 15     4
# 16     4
# 17     4
# 18     4
# 19     4
# 20     4
# 21     4
# 22     4
# 23     4
# 24     4
# 25     4
# ...

# %%
#Converting Screen Size Values into Floats
for i in range(len(gaming_laptops_df["screen"])):
    gaming_laptops_df["screen"] = float(gaming_laptops_df.loc[i,"screen"].replace('"',''))
    print(gaming_laptops_df["screen"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-30283f105549> in <module>
#       1 #Converting Screen Size Values into Floats
#       2 for i in range(len(gaming_laptops_df["screen"])):
# ----> 3     gaming_laptops_df["screen"] = float(gaming_laptops_df.loc[i,"screen"].replace('"',''))
#       4     print(gaming_laptops_df["screen"])
#
# AttributeError: 'numpy.float64' object has no attribute 'replace'

# %%
#Recommending Laptops based on number of Cores
gaming_laptops_df.cores.unique()
# Out:
# array(['6-core Processor', 'Quad-core Processor', -1, '8-core Processor',
#        '4-core Processor', 'Dual-core Processor', 'Six-core Processor',
#        '6'], dtype=object)

# %%
for i in range(len(gaming_laptops_df["cores"])):
    if "-1" in gaming_laptops_df["cores"]:
        pass
    elif "Dual" in gaming_laptops_df["cores"]:
        gaming_laptops_df.loc[i,"cores"] = 2
    elif "Quad"  in gaming_laptops_df["cores"] or "4" in gaming_laptops_df["cores"]:
        gaming_laptops_df.loc[i,"cores"] = 4
    elif "Six" in gaming_laptops_df["cores"] or "6" in gaming_laptops_df["cores"]:
        gaming_laptops_df.loc[i,"cores"] = 6
    elif "8" in gaming_laptops_df["cores"]:
        gaming_laptops_df.loc[i,"cores"] = 8
    #print(gaming_laptops_df.cores.unique())
# Out:
# ['6-core Processor' 'Quad-core Processor' -1 '8-core Processor'
#  '4-core Processor' 'Dual-core Processor' 'Six-core Processor' '6']
# ['6-core Processor' 'Quad-core Processor' -1 '8-core Processor'
#  '4-core Processor' 'Dual-core Processor' 'Six-core Processor' '6']
# ['6-core Processor' 'Quad-core Processor' -1 '8-core Processor'
#  '4-core Processor' 'Dual-core Processor' 'Six-core Processor' '6']
# ['6-core Processor' 'Quad-core Processor' -1 '8-core Processor'
#  '4-core Processor' 'Dual-core Processor' 'Six-core Processor' '6']
# ['6-core Processor' 'Quad-core Processor' -1 '8-core Processor'
#  '4-core Processor' 'Dual-core Processor' 'Six-core Processor' '6']
# ['6-core Processor' 'Quad-core Processor' -1 '8-core Processor'
#  '4-core Processor' 'Dual-core Processor' 'Six-core Processor' '6']
# ['6-core Processor' 'Quad-core Processor' -1 '8-core Processor'
#  '4-core Processor' 'Dual-core Processor' 'Six-core Processor' '6']
# ...

# %%
#Recommending Laptops based on GPU
gaming_laptops_df.gpu_type.unique()
# Out:
# array(['NVIDIA GeForce GTX 1050 Ti', 'NVIDIA GeForce RTX 2060',
#        'NVIDIA GeForce GTX 1650', 'NVIDIA GeForce RTX 2070',
#        'NVIDIA GeForce GTX 1660 Ti', 'NVIDIA GeForce GTX 1650 Max-Q', -1,
#        'NVIDIA GeForce GTX 1050', 'NVIDIA GeForce RTX 2080',
#        'AMD Radeon RX Vega 56', 'NVIDIA GeForce GTX 1060',
#        'GeForce GTX 1660 Ti', 'NVIDIA GeForce GTX 1080',
#        'AMD Radeon RX 5500M', 'GeForce GTX 1650', 'AMD Radeon RX 560X',
#        'NVIDIA GeForce GTX 1070 Max-Q', 'NVIDIA GeForce RTX 2080 Max-Q',
#        'NVIDIA GeForce GTX 1070', 'AMD Radeon 530',
#        'NVIDIA GeForce GTX 960M', 'NVIDIA GeForce GTX 860M',
#        'NVIDIA GeForce GTX 1070 SLI', 'Integrated Graphics',
#        'NVIDIA GeForce GTX 970M', 'NVIDIA GeForce GTX 950M',
#        'GeForce GTX1050', 'NVIDIA GeForce MX150',
#        'NVIDIA GeForce GTX 980', 'AMD Radeon RX Vega M GL'], dtype=object)

# %%
for i in range(len(gaming_laptops_df["gpu_type"])):
    if "-1" in gaming_laptops_df["gpu_type"]:
        pass
    elif "AMD Radeon RX Vega M Gl" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 1
    elif "Integrated Grpahics" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 2
    elif "AMD Radeon RX Vega 56" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 56
    elif "NVIDIA GeForce MX150" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 150
    elif "AMD Radeon RX 560X" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 560
    elif "NVIDIA GeForce GTX 860M" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 860
    elif "NVIDIA GeForce GTX 950M" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 950
    elif "NVIDIA GeForce GTX 960M" in gaming_laptops_df["gpu_type"]:
        gaming_laptpops_df.loc[i,"gpu_type"] = 960
    elif "NVIDIA GeForce GTX 970M" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 970
    elif "NVIDIA GeForce GTX 980" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 980
    elif "NVIDIA GeForce GTX 1050 Ti" in gaming_laptops_df["gpu_type"] or "NVIDIA GeForce GTX 1050" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 1050
    elif "NVIDIA GeForce GTX 1060" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 1060
    elif "NVIDIA GeForce GTX 1070 Max-Q" in gaming_laptops_df["gpu_type"] or "NVIDIA GeForce GTX 1070" in gaming_laptops_df["gpu_type"] or "NVIDIA GeForce GTX 1070 SLI" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 1070
    elif "NVIDIA GeForce GTX 1080" in gaming_laptops_df["gpu_type"]:
        gaming_laptops_df.loc[i,"gpu_type"] = 1080
    elif "NVIDIA GeForce GTX 1650" in gaming_laptops_df["gpu_types"] or "NVIDIA GeForce GTX 1650 Max-Q" in gaming_laptops_df["gpu_types"] or "GeForce GTX 1650 Ti":
        gaming_laptops_df.loc[i,"gpu_type"] = 1650
    elif ""

# %%
#Recommeding Laptops based on GPU's memory
gaming_laptops_df.gpu_memory.unique()
# Out:
# array(['4 GB', '6 GB', '8 GB', -1, 'Up to 4 GB', '2 GB', '3 GB',
#        '6G GDDR6', '4 GB GDDR5', '16 GB (8 GB each)',
#        'Shared system memory'], dtype=object)

# %%
for i in range(len(gaming_laptops_df["gpu_memory"])):
    if "-1" in gaming_laptops_df["gpu_memory"]:
        pass
    elif "shared system memory" in gaming_laptops_df["gpu_memory"]:
        gaming_laptops_df.loc[i,"gpu_memory"] = 1
    elif "2" in gaming_laptops_df["gpu_memory"]:
        gaming_laptops_df.loc[i,"gpu_memory"] = 2
    elif "3" in gaming_laptops_df["gpu_memory"]:
        gaming_laptops_df.loc[i,"gpu_memory"] = 3
    elif "4" in gaming_laptops_df["gpu_memory"] or "Up to 4" in gaming_laptops_df["gpu_memory"] or "4 GB GDDR5" in gaming_laptops_df["gpu_memory"]:
        gaming_laptops_df.loc[i,"gpu_memory"] = 4
    elif "6" in gaming_laptops_df["gpu_memory"] or "6G GDDR6" in gaming_laptops_df["gpu_memory"]:
        gaming_laptops_df.loc[i,"gpu_memory"] = 6
    elif "16" in gaming_laptops_df["gpu_memory"]:
        gaming_laptops_df.loc[i,"gpu_memory"] = 16
    #print(gaming_laptops_df.gpu_memory.unique())
# Out:
# ['4 GB' '6 GB' '8 GB' -1 'Up to 4 GB' '2 GB' '3 GB' '6G GDDR6'
#  '4 GB GDDR5' '16 GB (8 GB each)' 'Shared system memory']
# ['4 GB' '6 GB' '8 GB' -1 'Up to 4 GB' '2 GB' '3 GB' '6G GDDR6'
#  '4 GB GDDR5' '16 GB (8 GB each)' 'Shared system memory']
# ['4 GB' '6 GB' '8 GB' -1 'Up to 4 GB' '2 GB' '3 GB' '6G GDDR6'
#  '4 GB GDDR5' '16 GB (8 GB each)' 'Shared system memory']
# ['4 GB' '6 GB' '8 GB' -1 'Up to 4 GB' '2 GB' '3 GB' '6G GDDR6'
#  '4 GB GDDR5' '16 GB (8 GB each)' 'Shared system memory']
# ['4 GB' '6 GB' '8 GB' -1 'Up to 4 GB' '2 GB' '3 GB' '6G GDDR6'
#  '4 GB GDDR5' '16 GB (8 GB each)' 'Shared system memory']
# ['4 GB' '6 GB' '8 GB' -1 'Up to 4 GB' '2 GB' '3 GB' '6G GDDR6'
#  '4 GB GDDR5' '16 GB (8 GB each)' 'Shared system memory']
# ['4 GB' '6 GB' '8 GB' -1 'Up to 4 GB' '2 GB' '3 GB' '6G GDDR6'
#  '4 GB GDDR5' '16 GB (8 GB each)' 'Shared system memory']
# ['4 GB' '6 GB' '8 GB' -1 'Up to 4 GB' '2 GB' '3 GB' '6G GDDR6'
#  '4 GB GDDR5' '16 GB (8 GB each)' 'Shared system memory']
# ...

# %%
#Recommonding Laptops based on CPU's Memory
gaming_laptops_df.cpu_speed.unique()
# Out:
# array(['9750H (2.60 GHz)', '2.60 GHz', '3550H (2.10 GHz)',
#        '9300H (2.40 GHz)', '3750H (2.30 GHz)', -1, '8300H (2.30 GHz)',
#        '8750H (2.20 GHz)', '9880H (2.30 GHz)', '3500U (2.10 GHz)',
#        '2700 (3.20 GHz)', '8950HK (2.90 GHz)', '9700K (3.60 GHz)',
#        '2.3 GHz', '9980HK (2.40 GHz)', '7700HQ (2.80 GHz)', '2.40 GHz',
#        '7300HQ (2.50 GHz)', '2.20 GHz', '2.70 GHz', '6700HQ (2.60 GHz)',
#        '2500U (2.00 GHz)', '4700HQ (2.40 GHz)', '9900K (3.60 GHz)',
#        '8850H (2.60 GHz)', '6300U (2.40 GHz)', '3.00 GHz',
#        '8250U (1.60 GHz)', '3.70 GHz', '3.60 GHz', '4720HQ (2.60 GHz)',
#        '3500+', '1.80 GHz', '2.50 GHz', '7820HK (2.90 GHz)', '2.9 GHz',
#        '6920HQ (2.90 GHz)', '6820HK (2.70 GHz)', '2.80 GHz', '3.10 GHz',
#        '8705G (3.10 GHz)'], dtype=object)

# %%
for i in range(len(gaming_laptops_df["cpu_speed"])):
    if "-1" in gaming_laptops_df["cpu_speed"]:
        pass
    elif "8250U" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 1.60
    elif "1.80" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 1.80
    elif "2500U" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.00
    elif "3500U" in gaming_laptops_df["cpu_speed"] or "3550H" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.10
    elif "3500+" in gaming_laptops_df["cpu_speed"] or "8750H" in gaming_laptops_df["cpu_speed"] or "2.20 GHz" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.20
    elif "3750H" in gaming_laptops_df["cpu_speed"] or "8300H" in gaming_laptops_df["cpu_speed"] or "9880H" in gaming_laptops_df["cpu_speed"] or "2.3 GHz" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.30
    elif "9300H" in gaming_laptops_df["cpu_speed"] or "9980HK" in gaming_laptops_df["cpu_speed"] or "2.40 GHz" in gaming_laptops_df["cpu_speed"] or "4700HQ" in gaming_laptops_df["cpu_speed"] or "6300U" in gaming_laptops_df["cpu_speed"] or "2.40 GHz" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.40
    elif "7300 HQ" in gaming_laptops_df["cpu_speed"] or "2.50 GHz" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.50
    elif "9750H" in gaming_laptops_df["cpu_speed"] or "2.60 GHz" in gaming_laptops_df["cpu_speed"] or "6700HQ" in gaming_laptops_df["cpu_speed"] or "8850H" in gaming_laptops_df["cpu_speed"] or "4720HQ" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.60
    elif "2,70 GHz" in gaming_laptops_df["cpu_speed"] or "6820HK" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.70
    elif "7700HQ" in gaming_laptops_df["cpu_speed"] or "2.80 GHz" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.80
    elif "8950HK" in gaming_laptops_df["cpu_speed"] or "7820HK" in gaming_laptops_df["cpu_speed"] or "2.9 GHz" in gaming_laptops_df["cpu_speed"] or "6920HQ" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 2.90
    elif "3.00 GHz" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 3.00
    elif "3.10 GHz" in gaming_laptops_df["cpu_speed"] or "8750G" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 3.10
    elif "2700" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 3.20
    elif "9700K" in gaming_laptops_df["cpu_speed"] or "9900K" in gaming_laptops_df["cpu_speed"] or "3.60 GHz" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 3.60
    elif "3.70 GHz" in gaming_laptops_df["cpu_speed"]:
        gaming_laptops_df.loc[i,"cpu_speed"] = 3.70
    #print(gaming_laptops_df.cpu_speed.unique())
# Out:
# ['9750H (2.60 GHz)' '2.60 GHz' '3550H (2.10 GHz)' '9300H (2.40 GHz)'
#  '3750H (2.30 GHz)' -1 '8300H (2.30 GHz)' '8750H (2.20 GHz)'
#  '9880H (2.30 GHz)' '3500U (2.10 GHz)' '2700 (3.20 GHz)'
#  '8950HK (2.90 GHz)' '9700K (3.60 GHz)' '2.3 GHz' '9980HK (2.40 GHz)'
#  '7700HQ (2.80 GHz)' '2.40 GHz' '7300HQ (2.50 GHz)' '2.20 GHz' '2.70 GHz'
#  '6700HQ (2.60 GHz)' '2500U (2.00 GHz)' '4700HQ (2.40 GHz)'
#  '9900K (3.60 GHz)' '8850H (2.60 GHz)' '6300U (2.40 GHz)' '3.00 GHz'
#  '8250U (1.60 GHz)' '3.70 GHz' '3.60 GHz' '4720HQ (2.60 GHz)' '3500+'
#  '1.80 GHz' '2.50 GHz' '7820HK (2.90 GHz)' '2.9 GHz' '6920HQ (2.90 GHz)'
#  '6820HK (2.70 GHz)' '2.80 GHz' '3.10 GHz' '8705G (3.10 GHz)']
# ['9750H (2.60 GHz)' '2.60 GHz' '3550H (2.10 GHz)' '9300H (2.40 GHz)'
#  '3750H (2.30 GHz)' -1 '8300H (2.30 GHz)' '8750H (2.20 GHz)'
#  '9880H (2.30 GHz)' '3500U (2.10 GHz)' '2700 (3.20 GHz)'
#  '8950HK (2.90 GHz)' '9700K (3.60 GHz)' '2.3 GHz' '9980HK (2.40 GHz)'
# ...
